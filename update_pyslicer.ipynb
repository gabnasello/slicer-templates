# %% [markdown]
# # 📦 Updating *pyslicer* from GitHub
# A clean guide to cloning and reinstalling the package in Slicer's Python environment.

# %% [markdown]
# ## 🧭 1. Clone the pyslicer Repository
# This command downloads the repository from GitHub into the current folder.

# %%
# !git clone https://github.com/gabnasello/pyslicer.git

# %% [markdown]
# ## 🔧 2. Install pyslicer in Slicer's Python Environment
# Uses PythonSlicer to install the package in editable mode.

# %%
# !sudo /slicer/bin/PythonSlicer -m pip install -e pyslicer[all]
